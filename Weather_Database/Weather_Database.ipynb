# %%
# Import the dependencies
import sys
sys.path.append("..")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime
from config import weather_api_key

# %%
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if i % 50 == 0 and i >=0:
        set_count += 1
        record_count += 1
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                         "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 2 of Set 2 | mezica
# Processing Record 3 of Set 2 | wennigsen
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | severo-kurilsk
# Processing Record 6 of Set 2 | konevo
# Processing Record 7 of Set 2 | cururupu
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | puerto palomas
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | kropotkin
# Processing Record 14 of Set 2 | aswan
# Processing Record 15 of Set 2 | cajibio
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | lumajang
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | otradnoye
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | bakchar
# Processing Record 22 of Set 2 | fare
# Processing Record 23 of Set 2 | erenhot
# Processing Record 24 of Set 2 | bara
# Processing Record 25 of Set 2 | revelstoke
# Processing Record 26 of Set 2 | ambovombe
# Processing Record 27 of Set 2 | mardin
# Processing Record 28 of Set 2 | rikitea
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | vila
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | aksu
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | rundu
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | leningradskiy
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | bossangoa
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | luderitz
# Processing Record 46 of Set 2 | mount gambier
# Processing Record 47 of Set 2 | mecca
# Processing Record 48 of Set 2 | shikhany
# Processing Record 49 of Set 2 | padang
# Processing Record 50 of Set 2 | atuona
# Processing Record 51 of Set 2 | inta
# Processing Record 53 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 54 of Set 3 | meulaboh
# Processing Record 55 of Set 3 | butaritari
# Processing Record 56 of Set 3 | ipira
# Processing Record 57 of Set 3 | dikson
# Processing Record 58 of Set 3 | lazaro cardenas
# Processing Record 59 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 60 of Set 3 | coquimbo
# Processing Record 61 of Set 3 | tasiilaq
# Processing Record 62 of Set 3 | saint anthony
# Processing Record 63 of Set 3 | cherskiy
# Processing Record 64 of Set 3 | walvis bay
# Processing Record 65 of Set 3 | sao joao da barra
# Processing Record 66 of Set 3 | arusha
# Processing Record 67 of Set 3 | kaitangata
# Processing Record 68 of Set 3 | salihorsk
# Processing Record 69 of Set 3 | udachnyy
# Processing Record 70 of Set 3 | albany
# Processing Record 71 of Set 3 | troitsko-pechorsk
# Processing Record 72 of Set 3 | jumla
# Processing Record 73 of Set 3 | rio grande
# Processing Record 74 of Set 3 | longyearbyen
# Processing Record 75 of Set 3 | puerto ayora
# Processing Record 76 of Set 3 | bambous virieux
# Processing Record 77 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 78 of Set 3 | college
# Processing Record 79 of Set 3 | belmopan
# Processing Record 80 of Set 3 | thompson
# Processing Record 81 of Set 3 | flinders
# Processing Record 82 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 83 of Set 3 | ilo
# Processing Record 84 of Set 3 | georgetown
# Processing Record 85 of Set 3 | hilo
# Processing Record 86 of Set 3 | komsomolskiy
# Processing Record 87 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 88 of Set 3 | saint-philippe
# Processing Record 89 of Set 3 | sahaswan
# Processing Record 90 of Set 3 | xining
# Processing Record 91 of Set 3 | urdoma
# Processing Record 92 of Set 3 | mormugao
# Processing Record 93 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 94 of Set 3 | anjar
# Processing Record 95 of Set 3 | chinsali
# Processing Record 96 of Set 3 | khatanga
# Processing Record 97 of Set 3 | saint george
# Processing Record 98 of Set 3 | pisco
# Processing Record 99 of Set 3 | east london
# Processing Record 100 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 101 of Set 3 | najran
# Processing Record 102 of Set 3 | hellvik
# Processing Record 104 of Set 4 | northam
# Processing Record 105 of Set 4 | carnarvon
# Processing Record 106 of Set 4 | budaun
# Processing Record 107 of Set 4 | port elizabeth
# Processing Record 108 of Set 4 | hithadhoo
# Processing Record 109 of Set 4 | nanortalik
# Processing Record 110 of Set 4 | mahebourg
# Processing Record 111 of Set 4 | namibe
# Processing Record 112 of Set 4 | kuala terengganu
# Processing Record 113 of Set 4 | bethel
# Processing Record 114 of Set 4 | jablah
# Processing Record 115 of Set 4 | mayumba
# Processing Record 116 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 117 of Set 4 | cape town
# Processing Record 118 of Set 4 | evensk
# Processing Record 119 of Set 4 | vardo
# Processing Record 120 of Set 4 | nikolskoye
# Processing Record 121 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 122 of Set 4 | coihaique
# Processing Record 123 of Set 4 | hermanus
# Processing Record 124 of Set 4 | tenenkou
# Processing Record 125 of Set 4 | vermillion
# Processing Record 126 of Set 4 | australind
# Processing Record 127 of Set 4 | beringovskiy
# Processing Record 128 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 129 of Set 4 | sangar
# Processing Record 130 of Set 4 | san rafael
# Processing Record 131 of Set 4 | naze
# Processing Record 132 of Set 4 | kavieng
# Processing Record 133 of Set 4 | gidam
# Processing Record 134 of Set 4 | cidreira
# Processing Record 135 of Set 4 | madang
# Processing Record 136 of Set 4 | westport
# Processing Record 137 of Set 4 | mamallapuram
# Processing Record 138 of Set 4 | upernavik
# Processing Record 139 of Set 4 | bengkulu
# Processing Record 140 of Set 4 | shishou
# Processing Record 141 of Set 4 | luba
# Processing Record 142 of Set 4 | orel-izumrud
# Processing Record 143 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 144 of Set 4 | hobyo
# Processing Record 145 of Set 4 | constitucion
# Processing Record 146 of Set 4 | stornoway
# Processing Record 147 of Set 4 | aksarka
# Processing Record 148 of Set 4 | novikovo
# Processing Record 149 of Set 4 | mukhanovo
# City not found. Skipping...
# Processing Record 150 of Set 4 | shestakovo
# Processing Record 151 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 152 of Set 4 | tuatapere
# Processing Record 153 of Set 4 | sobolevo
# Processing Record 155 of Set 5 | kieta
# Processing Record 156 of Set 5 | homer
# Processing Record 157 of Set 5 | hobart
# Processing Record 158 of Set 5 | new norfolk
# Processing Record 159 of Set 5 | konstantinovka
# Processing Record 160 of Set 5 | barrow
# Processing Record 161 of Set 5 | half moon bay
# Processing Record 162 of Set 5 | la ronge
# Processing Record 163 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 164 of Set 5 | ngama
# Processing Record 165 of Set 5 | port alfred
# Processing Record 166 of Set 5 | kamenka
# Processing Record 167 of Set 5 | santa helena de goias
# Processing Record 168 of Set 5 | korla
# Processing Record 169 of Set 5 | evans
# Processing Record 170 of Set 5 | qaanaaq
# Processing Record 171 of Set 5 | blagoyevo
# Processing Record 172 of Set 5 | lompoc
# Processing Record 173 of Set 5 | lata
# Processing Record 174 of Set 5 | san lorenzo
# Processing Record 175 of Set 5 | jiayuguan
# Processing Record 176 of Set 5 | bonavista
# Processing Record 177 of Set 5 | liberal
# Processing Record 178 of Set 5 | ballina
# Processing Record 179 of Set 5 | kahului
# Processing Record 180 of Set 5 | san patricio
# Processing Record 181 of Set 5 | calabar
# Processing Record 182 of Set 5 | moose factory
# Processing Record 183 of Set 5 | mocuba
# Processing Record 184 of Set 5 | catuday
# Processing Record 185 of Set 5 | pervoye maya
# Processing Record 186 of Set 5 | margate
# Processing Record 187 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 188 of Set 5 | karasjok
# Processing Record 189 of Set 5 | narsaq
# Processing Record 190 of Set 5 | chodavaram
# Processing Record 191 of Set 5 | victoria
# Processing Record 192 of Set 5 | saint-joseph
# Processing Record 193 of Set 5 | paragominas
# Processing Record 194 of Set 5 | teul
# City not found. Skipping...
# Processing Record 195 of Set 5 | los llanos de aridane
# Processing Record 196 of Set 5 | olafsvik
# Processing Record 197 of Set 5 | turukhansk
# Processing Record 198 of Set 5 | sitka
# Processing Record 199 of Set 5 | colares
# Processing Record 200 of Set 5 | elat
# Processing Record 201 of Set 5 | mar del plata
# Processing Record 202 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 203 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 204 of Set 5 | esperance
# Processing Record 206 of Set 6 | mackay
# Processing Record 207 of Set 6 | polis
# Processing Record 208 of Set 6 | umm kaddadah
# Processing Record 209 of Set 6 | abu zabad
# Processing Record 210 of Set 6 | troitskoye
# Processing Record 211 of Set 6 | chuy
# Processing Record 212 of Set 6 | chara
# Processing Record 213 of Set 6 | clarence town
# Processing Record 214 of Set 6 | vila do maio
# Processing Record 215 of Set 6 | kodiak
# Processing Record 216 of Set 6 | hambantota
# Processing Record 217 of Set 6 | khash
# Processing Record 218 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 219 of Set 6 | provideniya
# Processing Record 220 of Set 6 | caucaia
# Processing Record 221 of Set 6 | santa rita
# Processing Record 222 of Set 6 | okha
# Processing Record 223 of Set 6 | bonthe
# Processing Record 224 of Set 6 | gao
# Processing Record 225 of Set 6 | meylan
# Processing Record 226 of Set 6 | grootfontein
# Processing Record 227 of Set 6 | jasper
# Processing Record 228 of Set 6 | avarua
# Processing Record 229 of Set 6 | kabansk
# Processing Record 230 of Set 6 | faanui
# Processing Record 231 of Set 6 | yuksekova
# Processing Record 232 of Set 6 | torres
# Processing Record 233 of Set 6 | moron
# Processing Record 234 of Set 6 | port hedland
# Processing Record 235 of Set 6 | aden
# Processing Record 236 of Set 6 | kampong chhnang
# Processing Record 237 of Set 6 | vostok
# Processing Record 238 of Set 6 | schwabmunchen
# Processing Record 239 of Set 6 | lodja
# Processing Record 240 of Set 6 | erechim
# Processing Record 241 of Set 6 | castro
# Processing Record 242 of Set 6 | graaff-reinet
# Processing Record 243 of Set 6 | eregli
# Processing Record 244 of Set 6 | cocobeach
# Processing Record 245 of Set 6 | chokurdakh
# Processing Record 246 of Set 6 | mandalgovi
# Processing Record 247 of Set 6 | san quintin
# Processing Record 248 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 249 of Set 6 | cabo san lucas
# Processing Record 250 of Set 6 | codrington
# Processing Record 251 of Set 6 | masterton
# Processing Record 252 of Set 6 | hamilton
# Processing Record 253 of Set 6 | shangzhi
# Processing Record 254 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 255 of Set 6 | north platte
# Processing Record 257 of Set 7 | lasa
# Processing Record 258 of Set 7 | pevek
# Processing Record 259 of Set 7 | boshnyakovo
# Processing Record 260 of Set 7 | noumea
# Processing Record 261 of Set 7 | eschwege
# Processing Record 262 of Set 7 | krasnoselkup
# Processing Record 263 of Set 7 | wabag
# Processing Record 264 of Set 7 | lichinga
# Processing Record 265 of Set 7 | pacific grove
# Processing Record 266 of Set 7 | hue
# Processing Record 267 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 268 of Set 7 | outlook
# Processing Record 269 of Set 7 | torbay
# Processing Record 270 of Set 7 | iralaya
# Processing Record 271 of Set 7 | itarema
# Processing Record 272 of Set 7 | qaqortoq
# Processing Record 273 of Set 7 | chapleau
# Processing Record 274 of Set 7 | lebu
# Processing Record 275 of Set 7 | booue
# Processing Record 276 of Set 7 | sao filipe
# Processing Record 277 of Set 7 | ponta do sol
# Processing Record 278 of Set 7 | maragogi
# Processing Record 279 of Set 7 | fort-shevchenko
# Processing Record 280 of Set 7 | aykhal
# Processing Record 281 of Set 7 | cortez
# Processing Record 282 of Set 7 | araouane
# Processing Record 283 of Set 7 | astoria
# Processing Record 284 of Set 7 | caravelas
# Processing Record 285 of Set 7 | shimoda
# Processing Record 286 of Set 7 | port lincoln
# Processing Record 287 of Set 7 | fallon
# Processing Record 288 of Set 7 | adolfo lopez mateos
# Processing Record 289 of Set 7 | surgut
# Processing Record 290 of Set 7 | tiksi
# Processing Record 291 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 292 of Set 7 | buta
# Processing Record 293 of Set 7 | elliot lake
# Processing Record 294 of Set 7 | tsentralnyy
# City not found. Skipping...
# Processing Record 295 of Set 7 | ust-tsilma
# Processing Record 296 of Set 7 | alofi
# Processing Record 297 of Set 7 | general pico
# Processing Record 298 of Set 7 | muros
# Processing Record 299 of Set 7 | santa rosa
# Processing Record 300 of Set 7 | baikunthpur
# Processing Record 301 of Set 7 | nalut
# Processing Record 302 of Set 7 | kirkwall
# Processing Record 303 of Set 7 | velasco ibarra
# Processing Record 304 of Set 7 | antofagasta
# Processing Record 305 of Set 7 | ulagan
# Processing Record 306 of Set 7 | pontianak
# Processing Record 308 of Set 8 | kodinsk
# Processing Record 309 of Set 8 | tautira
# Processing Record 310 of Set 8 | clyde river
# Processing Record 311 of Set 8 | ouadda
# Processing Record 312 of Set 8 | oistins
# Processing Record 313 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 314 of Set 8 | lagoa formosa
# Processing Record 315 of Set 8 | jizan
# Processing Record 316 of Set 8 | kavaratti
# Processing Record 317 of Set 8 | khandagayty
# Processing Record 318 of Set 8 | katete
# Processing Record 319 of Set 8 | luoyang
# Processing Record 320 of Set 8 | longyan
# Processing Record 321 of Set 8 | alice springs
# Processing Record 322 of Set 8 | sistranda
# Processing Record 323 of Set 8 | phan thiet
# Processing Record 324 of Set 8 | devils lake
# Processing Record 325 of Set 8 | dakar
# Processing Record 326 of Set 8 | bud
# Processing Record 327 of Set 8 | saldanha
# Processing Record 328 of Set 8 | kununurra
# Processing Record 329 of Set 8 | tecoanapa
# Processing Record 330 of Set 8 | panaba
# Processing Record 331 of Set 8 | launceston
# Processing Record 332 of Set 8 | fort nelson
# Processing Record 333 of Set 8 | sokolow podlaski
# Processing Record 334 of Set 8 | cardenas
# Processing Record 335 of Set 8 | kastamonu
# Processing Record 336 of Set 8 | egvekinot
# Processing Record 337 of Set 8 | vaitape
# Processing Record 338 of Set 8 | cooma
# Processing Record 339 of Set 8 | santa brigida
# Processing Record 340 of Set 8 | ayagoz
# Processing Record 341 of Set 8 | kalianget
# Processing Record 342 of Set 8 | laguna de perlas
# Processing Record 343 of Set 8 | black river
# Processing Record 344 of Set 8 | nicoya
# Processing Record 345 of Set 8 | norman wells
# Processing Record 346 of Set 8 | luis correia
# Processing Record 347 of Set 8 | haines junction
# Processing Record 348 of Set 8 | port macquarie
# Processing Record 349 of Set 8 | bolshaya murta
# City not found. Skipping...
# Processing Record 350 of Set 8 | granard
# Processing Record 351 of Set 8 | fairbanks
# Processing Record 352 of Set 8 | yulara
# Processing Record 353 of Set 8 | avera
# Processing Record 354 of Set 8 | port blair
# Processing Record 355 of Set 8 | poum
# Processing Record 356 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 357 of Set 8 | danville
# Processing Record 359 of Set 9 | klaksvik
# Processing Record 360 of Set 9 | kaeo
# Processing Record 361 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 362 of Set 9 | nambucca heads
# Processing Record 363 of Set 9 | sur
# Processing Record 364 of Set 9 | mungeli
# Processing Record 365 of Set 9 | motul
# Processing Record 366 of Set 9 | acajutla
# Processing Record 367 of Set 9 | hibbing
# Processing Record 368 of Set 9 | bagan
# Processing Record 369 of Set 9 | tuy hoa
# Processing Record 370 of Set 9 | sao jose da coroa grande
# Processing Record 371 of Set 9 | buchanan
# Processing Record 372 of Set 9 | micheweni
# Processing Record 373 of Set 9 | emerald
# Processing Record 374 of Set 9 | shitanjing
# Processing Record 375 of Set 9 | talaya
# Processing Record 376 of Set 9 | mahibadhoo
# Processing Record 377 of Set 9 | pontes e lacerda
# Processing Record 378 of Set 9 | scarborough
# Processing Record 379 of Set 9 | grindavik
# Processing Record 380 of Set 9 | martapura
# Processing Record 381 of Set 9 | garissa
# Processing Record 382 of Set 9 | morgantown
# Processing Record 383 of Set 9 | severnyy
# Processing Record 384 of Set 9 | acapulco
# Processing Record 385 of Set 9 | iqaluit
# Processing Record 386 of Set 9 | nyurba
# Processing Record 387 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 388 of Set 9 | varangaon
# Processing Record 389 of Set 9 | neuquen
# Processing Record 390 of Set 9 | naco
# Processing Record 391 of Set 9 | pringsewu
# Processing Record 392 of Set 9 | aplahoue
# Processing Record 393 of Set 9 | dalbandin
# Processing Record 394 of Set 9 | igarka
# Processing Record 395 of Set 9 | almaznyy
# Processing Record 396 of Set 9 | methoni
# Processing Record 397 of Set 9 | mukacheve
# Processing Record 398 of Set 9 | geraldton
# Processing Record 399 of Set 9 | ascension
# Processing Record 400 of Set 9 | marzuq
# Processing Record 401 of Set 9 | humen
# Processing Record 402 of Set 9 | jiangyou
# Processing Record 403 of Set 9 | aklavik
# Processing Record 404 of Set 9 | sartell
# Processing Record 405 of Set 9 | puerto escondido
# Processing Record 406 of Set 9 | porto santo
# Processing Record 407 of Set 9 | hurghada
# Processing Record 408 of Set 9 | moratuwa
# Processing Record 410 of Set 10 | cienaga de oro
# Processing Record 411 of Set 10 | lavrentiya
# Processing Record 412 of Set 10 | shubarshi
# Processing Record 413 of Set 10 | asau
# Processing Record 414 of Set 10 | eureka
# Processing Record 415 of Set 10 | baruun-urt
# Processing Record 416 of Set 10 | souillac
# Processing Record 417 of Set 10 | muzhi
# Processing Record 418 of Set 10 | cayenne
# Processing Record 419 of Set 10 | vitim
# Processing Record 420 of Set 10 | kruisfontein
# Processing Record 421 of Set 10 | kamaishi
# Processing Record 422 of Set 10 | platteville
# Processing Record 423 of Set 10 | talnakh
# Processing Record 424 of Set 10 | lorengau
# Processing Record 425 of Set 10 | anadyr
# Processing Record 426 of Set 10 | maxixe
# Processing Record 427 of Set 10 | hurricane
# Processing Record 428 of Set 10 | beaverlodge
# Processing Record 429 of Set 10 | nuuk
# Processing Record 430 of Set 10 | vila velha
# Processing Record 431 of Set 10 | rincon
# Processing Record 432 of Set 10 | fort madison
# Processing Record 433 of Set 10 | halifax
# Processing Record 434 of Set 10 | vao
# Processing Record 435 of Set 10 | talagang
# Processing Record 436 of Set 10 | bialogard
# Processing Record 437 of Set 10 | vestmannaeyjar
# Processing Record 438 of Set 10 | barra do garcas
# Processing Record 439 of Set 10 | knysna
# Processing Record 440 of Set 10 | kargil
# Processing Record 441 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 442 of Set 10 | brooks
# Processing Record 443 of Set 10 | san cristobal
# Processing Record 444 of Set 10 | cartagena
# Processing Record 445 of Set 10 | zhucheng
# Processing Record 446 of Set 10 | rockland
# Processing Record 447 of Set 10 | henties bay
# Processing Record 448 of Set 10 | salinopolis
# Processing Record 449 of Set 10 | laguna
# Processing Record 450 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 451 of Set 10 | sambava
# Processing Record 452 of Set 10 | sao raimundo nonato
# Processing Record 453 of Set 10 | nueva concepcion
# Processing Record 454 of Set 10 | sinnamary
# Processing Record 455 of Set 10 | touros
# Processing Record 456 of Set 10 | yinchuan
# Processing Record 457 of Set 10 | beloha
# Processing Record 458 of Set 10 | san policarpo
# Processing Record 459 of Set 10 | honiara
# Processing Record 461 of Set 11 | celestun
# Processing Record 462 of Set 11 | pirapo
# Processing Record 463 of Set 11 | kefamenanu
# Processing Record 464 of Set 11 | meadow lake
# Processing Record 465 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 466 of Set 11 | isangel
# Processing Record 467 of Set 11 | kirakira
# Processing Record 468 of Set 11 | paracuru
# Processing Record 469 of Set 11 | hami
# Processing Record 470 of Set 11 | soe
# Processing Record 471 of Set 11 | tiznit
# Processing Record 472 of Set 11 | taltal
# Processing Record 473 of Set 11 | camabatela
# Processing Record 474 of Set 11 | woodway
# Processing Record 475 of Set 11 | grand gaube
# Processing Record 476 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 477 of Set 11 | desaguadero
# Processing Record 478 of Set 11 | zhanaozen
# Processing Record 479 of Set 11 | qingdao
# Processing Record 480 of Set 11 | khomeyn
# Processing Record 481 of Set 11 | tezu
# Processing Record 482 of Set 11 | santander jimenez
# Processing Record 483 of Set 11 | concordia
# Processing Record 484 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 485 of Set 11 | henzada
# City not found. Skipping...
# Processing Record 486 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 487 of Set 11 | mindelo
# Processing Record 488 of Set 11 | sawtell
# Processing Record 489 of Set 11 | brookings
# Processing Record 490 of Set 11 | pangnirtung
# Processing Record 491 of Set 11 | oktyabrskiy
# Processing Record 492 of Set 11 | gamba
# Processing Record 493 of Set 11 | ballarat
# Processing Record 494 of Set 11 | goderich
# Processing Record 495 of Set 11 | mont-de-marsan
# Processing Record 496 of Set 11 | yeppoon
# Processing Record 497 of Set 11 | sioux lookout
# Processing Record 498 of Set 11 | pinawa
# Processing Record 499 of Set 11 | gbarnga
# Processing Record 500 of Set 11 | banda aceh
# Processing Record 501 of Set 11 | lebanon
# Processing Record 502 of Set 11 | broken hill
# Processing Record 503 of Set 11 | amahai
# Processing Record 504 of Set 11 | samarai
# Processing Record 505 of Set 11 | warrington
# Processing Record 506 of Set 11 | iluppur
# Processing Record 507 of Set 11 | alugan
# Processing Record 508 of Set 11 | mudanjiang
# Processing Record 509 of Set 11 | grand-santi
# Processing Record 510 of Set 11 | boyarka
# Processing Record 512 of Set 12 | sorland
# Processing Record 513 of Set 12 | sovetskoye
# Processing Record 514 of Set 12 | amudat
# Processing Record 515 of Set 12 | koslan
# Processing Record 516 of Set 12 | sisimiut
# Processing Record 517 of Set 12 | banjar
# Processing Record 518 of Set 12 | tiarei
# Processing Record 519 of Set 12 | sterling
# Processing Record 520 of Set 12 | felipe carrillo puerto
# Processing Record 521 of Set 12 | brae
# Processing Record 522 of Set 12 | la ligua
# Processing Record 523 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 524 of Set 12 | enshi
# Processing Record 525 of Set 12 | kota kinabalu
# Processing Record 526 of Set 12 | verkhnetulomskiy
# Processing Record 527 of Set 12 | galle
# Processing Record 528 of Set 12 | visavadar
# Processing Record 529 of Set 12 | upata
# Processing Record 530 of Set 12 | tomatlan
# Processing Record 531 of Set 12 | vikhorevka
# Processing Record 532 of Set 12 | stokmarknes
# Processing Record 533 of Set 12 | ipilan
# Processing Record 534 of Set 12 | andenes
# Processing Record 535 of Set 12 | constantine
# Processing Record 536 of Set 12 | port moresby
# Processing Record 537 of Set 12 | manggar
# Processing Record 538 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 539 of Set 12 | ahipara
# Processing Record 540 of Set 12 | dunedin
# Processing Record 541 of Set 12 | honningsvag
# Processing Record 542 of Set 12 | havelock
# Processing Record 543 of Set 12 | fortuna
# Processing Record 544 of Set 12 | la palma
# Processing Record 545 of Set 12 | isiro
# Processing Record 546 of Set 12 | kopargaon
# Processing Record 547 of Set 12 | mulanje
# Processing Record 548 of Set 12 | karatau
# Processing Record 549 of Set 12 | rawson
# Processing Record 550 of Set 12 | shache
# Processing Record 551 of Set 12 | antequera
# Processing Record 552 of Set 12 | jishou
# Processing Record 553 of Set 12 | bontang
# Processing Record 554 of Set 12 | pryazha
# Processing Record 555 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 556 of Set 12 | belyy yar
# Processing Record 557 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 558 of Set 12 | los algarrobos
# Processing Record 559 of Set 12 | santa vitoria do palmar
# Processing Record 560 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 561 of Set 12 | mogok
# Processing Record 563 of Set 13 | gimbi
# Processing Record 564 of Set 13 | majene
# Processing Record 565 of Set 13 | areia branca
# Processing Record 566 of Set 13 | salalah
# Processing Record 567 of Set 13 | abu kamal
# Processing Record 568 of Set 13 | port hardy
# Processing Record 569 of Set 13 | ondjiva
# Processing Record 570 of Set 13 | matay
# Processing Record 571 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 572 of Set 13 | hede
# Processing Record 573 of Set 13 | country club
# Processing Record 574 of Set 13 | ketchikan
# Processing Record 575 of Set 13 | bantry
# Processing Record 576 of Set 13 | ancud
# Processing Record 577 of Set 13 | kirksville
# Processing Record 578 of Set 13 | jega
# Processing Record 579 of Set 13 | formosa
# Processing Record 580 of Set 13 | svetlogorsk
# Processing Record 581 of Set 13 | rangia
# Processing Record 582 of Set 13 | zempoala
# Processing Record 583 of Set 13 | portland
# Processing Record 584 of Set 13 | shingu
# Processing Record 585 of Set 13 | san jeronimo
# Processing Record 586 of Set 13 | mount pleasant
# Processing Record 587 of Set 13 | teya
# Processing Record 588 of Set 13 | sabha
# Processing Record 589 of Set 13 | gravelbourg
# Processing Record 590 of Set 13 | erdenet
# Processing Record 591 of Set 13 | wuxue
# Processing Record 592 of Set 13 | burica
# City not found. Skipping...
# Processing Record 593 of Set 13 | hofn
# Processing Record 594 of Set 13 | khawhai
# Processing Record 595 of Set 13 | rorvik
# Processing Record 596 of Set 13 | igrim
# Processing Record 597 of Set 13 | tetiz
# Processing Record 598 of Set 13 | ulladulla
# Processing Record 599 of Set 13 | faro
# Processing Record 600 of Set 13 | mount isa
# Processing Record 601 of Set 13 | krasnoarmeysk
# Processing Record 602 of Set 13 | kostomuksha
# Processing Record 603 of Set 13 | makushino
# Processing Record 604 of Set 13 | roma
# Processing Record 605 of Set 13 | lakhdenpokhya
# Processing Record 606 of Set 13 | tamandare
# Processing Record 607 of Set 13 | inuvik
# Processing Record 608 of Set 13 | gizo
# Processing Record 609 of Set 13 | harnosand
# Processing Record 610 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 611 of Set 13 | marsh harbour
# Processing Record 612 of Set 13 | tazovskiy
# Processing Record 614 of Set 14 | kenora
# Processing Record 615 of Set 14 | nagutskoye
# Processing Record 616 of Set 14 | lexington
# Processing Record 617 of Set 14 | villamontes
# Processing Record 618 of Set 14 | batticaloa
# Processing Record 619 of Set 14 | yenagoa
# Processing Record 620 of Set 14 | agropoli
# Processing Record 621 of Set 14 | iracoubo
# Processing Record 622 of Set 14 | teplodar
# Processing Record 623 of Set 14 | hendijan
# City not found. Skipping...
# Processing Record 624 of Set 14 | alta floresta
# Processing Record 625 of Set 14 | ostrovnoy
# Processing Record 626 of Set 14 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 627 of Set 14 | huarmey
# Processing Record 628 of Set 14 | paamiut
# Processing Record 629 of Set 14 | vitimskiy
# City not found. Skipping...
# Processing Record 630 of Set 14 | onokhoy
# Processing Record 631 of Set 14 | phek
# Processing Record 632 of Set 14 | marang
# Processing Record 633 of Set 14 | srandakan
# Processing Record 634 of Set 14 | gilbues
# Processing Record 635 of Set 14 | barahona
# Processing Record 636 of Set 14 | saint-louis
# Processing Record 637 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 638 of Set 14 | sete
# Processing Record 639 of Set 14 | oyem
# Processing Record 640 of Set 14 | staritsa
# Processing Record 641 of Set 14 | badin
# Processing Record 642 of Set 14 | altamira
# Processing Record 643 of Set 14 | goure
# Processing Record 644 of Set 14 | ejura
# Processing Record 645 of Set 14 | ilulissat
# Processing Record 646 of Set 14 | sorso
# Processing Record 647 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 648 of Set 14 | praia
# Processing Record 649 of Set 14 | guerrero negro
# Processing Record 650 of Set 14 | pemangkat
# Processing Record 651 of Set 14 | waddan
# Processing Record 652 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 653 of Set 14 | namatanai
# Processing Record 654 of Set 14 | peniche
# Processing Record 655 of Set 14 | mehamn
# Processing Record 656 of Set 14 | plaridel
# Processing Record 657 of Set 14 | sembe
# Processing Record 658 of Set 14 | yarmouth
# Processing Record 659 of Set 14 | taoudenni
# Processing Record 660 of Set 14 | dhidhdhoo
# Processing Record 661 of Set 14 | adelaide
# Processing Record 662 of Set 14 | neiafu
# Processing Record 663 of Set 14 | shakawe
# Processing Record 665 of Set 15 | batemans bay
# Processing Record 666 of Set 15 | parrita
# Processing Record 667 of Set 15 | husavik
# Processing Record 668 of Set 15 | zanjan
# Processing Record 669 of Set 15 | borogontsy
# Processing Record 670 of Set 15 | tororo
# Processing Record 671 of Set 15 | inhambane
# Processing Record 672 of Set 15 | mumford
# Processing Record 673 of Set 15 | gulariya
# Processing Record 674 of Set 15 | dawlatabad
# Processing Record 675 of Set 15 | povoa de varzim
# Processing Record 676 of Set 15 | qandala
# Processing Record 677 of Set 15 | dehloran
# Processing Record 678 of Set 15 | chapais
# Processing Record 679 of Set 15 | champerico
# Processing Record 680 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 681 of Set 15 | ikole
# City not found. Skipping...
# Processing Record 682 of Set 15 | illapel
# Processing Record 683 of Set 15 | sindou
# Processing Record 684 of Set 15 | belmonte
# Processing Record 685 of Set 15 | kataysk
# Processing Record 686 of Set 15 | labuhan
# Processing Record 687 of Set 15 | sujiatun
# Processing Record 688 of Set 15 | madera
# Processing Record 689 of Set 15 | songjianghe
# Processing Record 690 of Set 15 | ambon
# Processing Record 691 of Set 15 | ulaanbaatar
# Processing Record 692 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 693 of Set 15 | bilibino
# Processing Record 694 of Set 15 | yerakion
# Processing Record 695 of Set 15 | erzin
# Processing Record 696 of Set 15 | turayf
# Processing Record 697 of Set 15 | gaoua
# Processing Record 698 of Set 15 | rosetta
# Processing Record 699 of Set 15 | jambi
# Processing Record 700 of Set 15 | nouakchott
# Processing Record 701 of Set 15 | maningrida
# Processing Record 702 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 703 of Set 15 | verkhniy avzyan
# Processing Record 704 of Set 15 | prieska
# Processing Record 705 of Set 15 | miri
# Processing Record 706 of Set 15 | bafilo
# Processing Record 707 of Set 15 | coari
# Processing Record 708 of Set 15 | mikhaylovskoye
# Processing Record 709 of Set 15 | sao felix do xingu
# Processing Record 710 of Set 15 | hirara
# Processing Record 711 of Set 15 | north myrtle beach
# Processing Record 712 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 713 of Set 15 | okhotsk
# Processing Record 714 of Set 15 | mettingen
# Processing Record 716 of Set 16 | kupang
# Processing Record 717 of Set 16 | soyo
# Processing Record 718 of Set 16 | matara
# Processing Record 719 of Set 16 | tutoia
# Processing Record 720 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 721 of Set 16 | akdepe
# Processing Record 722 of Set 16 | stoyba
# City not found. Skipping...
# Processing Record 723 of Set 16 | grand island
# Processing Record 724 of Set 16 | gilgit
# Processing Record 725 of Set 16 | arman
# Processing Record 726 of Set 16 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 727 of Set 16 | baillif
# Processing Record 728 of Set 16 | tilichiki
# Processing Record 729 of Set 16 | dibaya
# City not found. Skipping...
# Processing Record 730 of Set 16 | cockburn town
# Processing Record 731 of Set 16 | morondava
# Processing Record 732 of Set 16 | takoradi
# Processing Record 733 of Set 16 | atagay
# Processing Record 734 of Set 16 | imeni poliny osipenko
# Processing Record 735 of Set 16 | taitung
# Processing Record 736 of Set 16 | canton
# Processing Record 737 of Set 16 | dekoa
# City not found. Skipping...
# Processing Record 738 of Set 16 | sri aman
# Processing Record 739 of Set 16 | hualmay
# Processing Record 740 of Set 16 | ola
# Processing Record 741 of Set 16 | bambanglipuro
# Processing Record 742 of Set 16 | vung tau
# Processing Record 743 of Set 16 | tessalit
# Processing Record 744 of Set 16 | williston
# Processing Record 745 of Set 16 | basco
# Processing Record 746 of Set 16 | bull savanna
# Processing Record 747 of Set 16 | tamale
# Processing Record 748 of Set 16 | crotone
# Processing Record 749 of Set 16 | ryotsu
# Processing Record 750 of Set 16 | bukama
# Processing Record 751 of Set 16 | san juan
# Processing Record 752 of Set 16 | kathu
# Processing Record 753 of Set 16 | den helder
# Processing Record 754 of Set 16 | tonantins
# Processing Record 755 of Set 16 | pochutla
# Processing Record 756 of Set 16 | dandong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Mezica      SI  46.52   14.85     75.99        70          94
# 1        Wennigsen      DE  52.27    9.57     70.00        60          20
# 2          Mataura      NZ -46.19  168.86     44.01        91          53
# 3   Severo-Kurilsk      RU  50.68  156.12     51.67        71          99
# 4           Konevo      RU  62.12   39.32     59.16        92         100
# 5         Cururupu      BR  -1.83  -44.87     81.03        86          47
# 6          Ushuaia      AR -54.80  -68.30     35.60        74          40
# 7     Punta Arenas      CL -53.15  -70.92     37.40        59          40
# 8   Puerto Palomas      MX  31.77 -107.62     87.80        22           1
# 9  Arraial Do Cabo      BR -22.97  -42.03     71.60        68          75
#
#    Wind Speed Current Description                 Date
# 0        3.00          light rain  2020-08-23 16:23:02
# 1       19.46          few clouds  2020-08-23 16:23:02
# 2        1.99       broken clouds  2020-08-23 16:16:45
# 3        5.12     overcast clouds  2020-08-23 16:21:37
# 4       10.33     overcast clouds  2020-08-23 16:20:06
# 5        6.64       moderate rain  2020-08-23 16:23:03
# 6       16.11         shower rain  2020-08-23 16:20:36
# 7       23.04    scattered clouds  2020-08-23 16:16:46
# 8        8.05           clear sky  2020-08-23 16:23:03
# 9        9.17       broken clouds  2020-08-23 16:20:39

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a csv.
city_data_df.to_csv(output_data_file, index_label="City_ID")
